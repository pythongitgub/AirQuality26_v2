# %%
import pandas as pd

sites = pd.read_csv("outputs/investigation_sites.csv")
monitors = pd.read_csv("outputs/air_monitor_registry.csv")

result = sites.merge(monitors, how="left")
result.to_csv("outputs/investigation_environment_context.csv", index=False)
